# %%
# %pip install ipympl

# %%
# %matplotlib widget 
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Projects/synthetic_rfq/.venv/lib/python3.13/site-packages/matplotlib/backends/registry.py:407, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     406 try:
# --> 407     return self.resolve_backend(gui_or_backend)
#     408 except Exception:  # KeyError ?
#
# File ~/Projects/synthetic_rfq/.venv/lib/python3.13/site-packages/matplotlib/backends/registry.py:369, in BackendRegistry.resolve_backend(self, backend)
#     368 if gui is None:
# --> 369     raise RuntimeError(f"'{backend}' is not a recognised backend name")
#     371 return backend, gui if gui != "headless" else None
#
# RuntimeError: 'widget' is not a recognised backend name
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ...

# %%
df = pd.read_csv("23_vendor_health_scores.csv")

# %%
df = df[df['vendor_id'].isin(['V001'])]

# %%
df.info()

# %%
plt.plot(df['month_index'],df['composite_health_score'])
